// %%
cout<<"Hello"<<endl;
// Out:
// Hello

// %%
TCanvas * c1 = new TCanvas("c1","c1");
TH1D * h1 = new TH1D("h1","h1",50,-1,1);
h1->FillRandom("gaus",20000);
h1->Draw();
c1->Draw()

// %%
h1->SetFillStyle(5);
h1->SetFillColor(kBlue);
h1->GetXaxis()->SetTitle("#Delta #phi");
h1->GetYaxis()->SetTitle("Events a.u.");
h1->GetXaxis()->CenterTitle();
h1->SetStats(0);
h1->SetTitle("A new histogram");
c1->Draw();
c1->SaveAs("c11.pdf");
c1->SaveAs("c11.C");
// Out:
// Info in <TCanvas::Print>: pdf file c11.pdf has been created
// Info in <TCanvas::SaveSource>: C++ Macro file: c11.C has been generated
