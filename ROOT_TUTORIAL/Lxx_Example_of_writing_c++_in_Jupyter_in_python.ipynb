# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.10/08

# %%
# %%cpp
# cout << "This is a C++ cell" << endl;
# Out:
# This is a C++ cell

# %%
# %%cpp
# TMath::Exp(0)
# Out:
# (double) 1.000000

# %%
# %%cpp
# TCanvas * c1 = new TCanvas("c1","c1");
# TH1D * h1 = new TH1D("h1","h1",50,-1,1);
# h1->FillRandom("gaus",20000);
# h1->Draw();
# c1->Draw()

# %%
# %%cpp
# h1->SetFillStyle(5);
# h1->SetFillColor(kRed);
# h1->GetXaxis()->SetTitle("#Delta #phi");
# h1->GetYaxis()->SetTitle("Events a.u.");
# h1->GetXaxis()->CenterTitle();
# h1->SetStats(0);
# h1->SetTitle("A new histogram");
# c1->Draw()

# %%
# %%cpp
# Double_t z = 1.06616;
# printf("This is awesome: %lg",z)
# Out:
# This is awesome: 1.06616(int) 24
